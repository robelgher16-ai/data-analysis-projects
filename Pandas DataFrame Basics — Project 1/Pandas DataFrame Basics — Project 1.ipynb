# %%
import pandas as pd

# %%
# Creating the dictionary
dict1 = {
    'Name': ['Priyang', 'Aadhya', 'Krisha', 'Vedant', 'Parshv', 'Mittal', 'Archana'],
    'Marks': [98, 89, 99, 87, 90, 83, 99],
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female']
}

# Creating the DataFrame
df = pd.DataFrame(dict1)

# Displaying the DataFrame
df
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# ### 1. Display Top 3 Rows of The Dataset

# %%
df.head(3)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female

# %% [markdown]
# ### 2. Display last 3 Rows of The Dataset

# %%
df.tail(3)
# Out:
#       Name  Marks  Gender
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# ### 3. Find Shape of Our Dataset (Number of Rows and Number of Columns)

# %%
df.shape
# Out:
# (7, 3)

# %%
print("Number of Rows :-  " , df.shape[0])
# Out:
# Number of Rows :-   7

# %%
print("Number of columns :- " , df.shape[1])
# Out:
# Number of columns :-  3

# %% [markdown]
# ### 4. Get information About our Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# ### 5. Check Null Value in The Dataset

# %%
df.isnull().sum(axis=0)  # 0 mean vertical and 1 mean horizontal
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %% [markdown]
# ### 6. Get Overall Statics About The Dataframe

# %%
df.describe(include= 'all')
# Out:
#            Name      Marks  Gender
# count         7   7.000000       7
# unique        7        NaN       2
# top     Priyang        NaN  Female
# freq          1        NaN       4
# mean        NaN  92.142857     NaN
# std         NaN   6.491753     NaN
# min         NaN  83.000000     NaN
# 25%         NaN  88.000000     NaN
# 50%         NaN  90.000000     NaN
# 75%         NaN  98.500000     NaN
# max         NaN  99.000000     NaN

# %% [markdown]
# ### 7. Find Unique value From The Gender Column

# %%
df['Gender'].unique()  # this tell you how many diffferent values are here there are 2 male and female
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# ### 8. Find the Number of Unique value From The Gender Column

# %%
df['Gender'].nunique()
# Out:
# 2

# %% [markdown]
# ### 9. Display Count of Unique Value in Gender Column

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    4
# Male      3
# Name: count, dtype: int64

# %% [markdown]
# ### 10. Find Total Number of Student Having Marks Between 90 To 100 (inclusive) Using Between Method

# %%
df[df["Marks"]>90]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 6  Archana     99  Female

# %%
len (df[(df['Marks']>=90) & (df['Marks']<=100 )])
# Out:
# 4

# %%
sum(df['Marks'].between(90,100))
# Out:
# 4

# %% [markdown]
# ### 11. Find Average Marks

# %%
print(df["Marks"].mean())
# Out:
# 92.14285714285714

# %%
df['Marks']
# Out:
# 0    98
# 1    89
# 2    99
# 3    87
# 4    90
# 5    83
# 6    99
# Name: Marks, dtype: int64

# %% [markdown]
# ### 12. Apply Method

# %%
def marks(x):
    return x/2

# %%
df['Marks'].apply(marks)
# Out:
# 0    49.0
# 1    44.5
# 2    49.5
# 3    43.5
# 4    45.0
# 5    41.5
# 6    49.5
# Name: Marks, dtype: float64

# %%
df['Half_Marks'] = df['Marks'].apply(marks)
df
# Out:
#       Name  Marks  Gender  Half_Marks
# 0  Priyang     98    Male        49.0
# 1   Aadhya     89  Female        44.5
# 2   Krisha     99  Female        49.5
# 3   Vedant     87    Male        43.5
# 4   Parshv     90    Male        45.0
# 5   Mittal     83  Female        41.5
# 6  Archana     99  Female        49.5

# %%
df['Marks'].apply(lambda x:x/2)
# Out:
# 0    49.0
# 1    44.5
# 2    49.5
# 3    43.5
# 4    45.0
# 5    41.5
# 6    49.5
# Name: Marks, dtype: float64

# %% [markdown]
# ### 13. Map Function

# %%
df['Name'].apply(len)
# Out:
# 0    7
# 1    6
# 2    6
# 3    6
# 4    6
# 5    6
# 6    7
# Name: Name, dtype: int64

# %%
df['Male_Female'] = df ['Gender'].map({'Male' : 1 , 'Female' : 0 })
df
# Out:
#       Name  Marks  Gender  Half_Marks  Male_Female
# 0  Priyang     98    Male        49.0            1
# 1   Aadhya     89  Female        44.5            0
# 2   Krisha     99  Female        49.5            0
# 3   Vedant     87    Male        43.5            1
# 4   Parshv     90    Male        45.0            1
# 5   Mittal     83  Female        41.5            0
# 6  Archana     99  Female        49.5            0

# %% [markdown]
# ### 14. Drop Column

# %%
df= df.drop('Male_Female', axis=1) 
df
# Out:
#       Name  Marks  Gender  Half_Marks
# 0  Priyang     98    Male        49.0
# 1   Aadhya     89  Female        44.5
# 2   Krisha     99  Female        49.5
# 3   Vedant     87    Male        43.5
# 4   Parshv     90    Male        45.0
# 5   Mittal     83  Female        41.5
# 6  Archana     99  Female        49.5

# %%
# df= df.drop(['Male_Female','Name'] , axis=1)  # to drop more column in one

# %%
df
# Out:
#       Name  Marks  Gender  Half_Marks
# 0  Priyang     98    Male        49.0
# 1   Aadhya     89  Female        44.5
# 2   Krisha     99  Female        49.5
# 3   Vedant     87    Male        43.5
# 4   Parshv     90    Male        45.0
# 5   Mittal     83  Female        41.5
# 6  Archana     99  Female        49.5

# %% [markdown]
# ### 15. Print Name of the Columns

# %%
df.columns
# Out:
# Index(['Name', 'Marks', 'Gender', 'Half_Marks'], dtype='object')

# %% [markdown]
# ### 16. Sort The Dataframe As Per The Marks Column

# %%
df.sort_values(by=['Marks','Gender'],ascending=False)
# Out:
#       Name  Marks  Gender  Half_Marks
# 2   Krisha     99  Female        49.5
# 6  Archana     99  Female        49.5
# 0  Priyang     98    Male        49.0
# 4   Parshv     90    Male        45.0
# 1   Aadhya     89  Female        44.5
# 3   Vedant     87    Male        43.5
# 5   Mittal     83  Female        41.5

# %% [markdown]
# ### 17. Display Name and Marks of The Female Students

# %%
df
# Out:
#       Name  Marks  Gender  Half_Marks
# 0  Priyang     98    Male        49.0
# 1   Aadhya     89  Female        44.5
# 2   Krisha     99  Female        49.5
# 3   Vedant     87    Male        43.5
# 4   Parshv     90    Male        45.0
# 5   Mittal     83  Female        41.5
# 6  Archana     99  Female        49.5

# %%
df[df['Gender']=='Female' ][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya     89
# 2   Krisha     99
# 5   Mittal     83
# 6  Archana     99

# %%
df[df['Gender'].isin(['Female'])][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya     89
# 2   Krisha     99
# 5   Mittal     83
# 6  Archana     99
